# %%
import pandas as pd

# %%
import json

# %%
import re

# %%
with open('My Activity.json') as f:
    data = json.load(f)

# %%
for key in data:
    key['products'] = key['products'][0]
    if key.get('locations', {}):
        key['locations-name'] = key['locations'][0]['name']
        key['locations-url']  = key['locations'][0]['url']
        key.pop('locations')

# %%
df = pd.DataFrame.from_records(data)

# %%
df['listened'] = df['title'].apply(lambda x: True if re.match('^Listened to ', x) is not None else False)
df['skipped'] = df['title'].apply(lambda x: True if re.match('^Skipped ', x) is not None else False)
df['searched'] = df['title'].apply(lambda x: True if re.match('^Searched for ', x) is not None else False)
df['title'] = df['title'].apply(lambda x: re.sub('^Listened to |^Skipped |^Searched for ', '', x))

# %%
temp = df.rename(columns={'description': 'artist', 'titleUrl':'searchresultURL'})

# %%
temp.to_csv('My Activity.csv', index=None)

# %%
temp.head()
# Out:
#             artist             header              locations-name  \
# 0           ODESZA  Google Play Music  From your current location
# 1         Illenium  Google Play Music  From your current location
# 2  Louis The Child  Google Play Music  From your current location
# 3         Jai Wolf  Google Play Music  From your current location
# 4           Trinix  Google Play Music  From your current location
#
#                                    locations-url           products  \
# 0  https://google.com/maps?q=17.442345,78.375244  Google Play Music
# 1  https://google.com/maps?q=17.442345,78.375244  Google Play Music
# 2  https://google.com/maps?q=17.442345,78.375244  Google Play Music
# 3  https://google.com/maps?q=17.442345,78.375244  Google Play Music
# 4  https://google.com/maps?q=17.442345,78.375244  Google Play Music
#
#                        time                        title searchresultURL  \
# 0  2018-12-18T05:23:57.242Z               A Moment Apart             NaN
# ...

# %%
temp['time'] =  pd.to_datetime(temp.time)

# %%
temp['dayofweek'] = temp.time.dt.day_name()

temp.groupby('dayofweek').size()
# Out:
# dayofweek
# Friday       1189
# Monday       1217
# Saturday      133
# Sunday        191
# Thursday     1716
# Tuesday      1266
# Wednesday    1728
# dtype: int64

# %%
import seaborn as sns
# %matplotlib inline
sns.countplot(x='dayofweek', data=temp)

# %%
temp[temp.time >= '2018-01-01']
# Out:
#                             artist             header  \
# 0                           ODESZA  Google Play Music
# 1                         Illenium  Google Play Music
# 2                  Louis The Child  Google Play Music
# 3                         Jai Wolf  Google Play Music
# 4                           Trinix  Google Play Music
# 5                            Melvv  Google Play Music
# 6                            Flume  Google Play Music
# 7                           ODESZA  Google Play Music
# 8                            Flume  Google Play Music
# 9                            Flume  Google Play Music
# 10                          ODESZA  Google Play Music
# 11                 Louis The Child  Google Play Music
# 12                        Jai Wolf  Google Play Music
# 13                           Flume  Google Play Music
# 14                          ODESZA  Google Play Music
# 15                 Louis The Child  Google Play Music
# ...

# %%
temp['month'] = temp.time.dt.month_name()

# %%
sns.countplot(x='month', hue='dayofweek', data=temp)

# %%
temp.groupby('artist').count().sort_values(by='header', ascending=False)
# Out:
#                                  header  locations-name  locations-url  \
# artist
# ODESZA                              222              84             84
# Florence + The Machine              115              41             41
# Kendrick Lamar                      111              13             13
# Childish Gambino                    110              19             19
# Kanye West                          101              32             32
# Leslie Odom Jr.                      91              10             10
# Foo Fighters                         83              34             34
# Lin-Manuel Miranda                   83              10             10
# Illenium                             76               8              8
# Jai Wolf                             61              15             15
# Chvrches                             55              36             36
# Imagine Dragons                      53              16             16
# ...

# %%
sns.countplot(x='artist', data=temp)
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fe0146f8950> (for post_execute):
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# ~/anaconda3/envs/gramex_local/lib/python3.7/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2514         try:
# -> 2515             result = self._expression.parseString(s)
#    2516         except ParseBaseException as err:
#
# ~/anaconda3/envs/gramex_local/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1631                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1632                 raise exc
#    1633         else:
#
# ~/anaconda3/envs/gramex_local/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1621         try:
# ...
